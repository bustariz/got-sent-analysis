# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import pandas as pd
from statistics import mean
import nltk
from pprint import pprint
from pymongo import MongoClient

# %%
# Reads in script from csv file and renames columns to lowercase
path = 'Game_of_Thrones_Script.csv'

script_df = pd.read_csv(path)

script_df = script_df.rename(columns = {'Release Date': 'release_date',
                                        'Season': 'season',
                                        'Episode':'episode',
                                        'Episode Title':'episode_title',
                                        'Name':'name', 
                                        'Sentence': 'sentence'
                                       })

# %%
# sentiment analysis for script df using vaderSentiment library


analyzer = SentimentIntensityAnalyzer()

sent_analysis = [analyzer.polarity_scores(sentence) for sentence in script_df.sentence]

# %%
# adds column to df for each polarity score (pos,compound,neu,neg)
script_df['positive_score'] = [key.get('pos') for key in sent_analysis]
script_df['compound_score'] = [key.get('compound') for key in sent_analysis]
script_df['neutral_score'] = [key.get('neu') for key in sent_analysis]
script_df['negative_score'] = [key.get('neg') for key in sent_analysis]

# using nltk to separate sentence into words and punctuation as a list and add as a column into df
script_df['tokenized_words'] = [nltk.word_tokenize(sentence)for sentence in script_df.sentence]


# tokenized_words column with punctuation removed 
script_df['alphanumeric_words'] = script_df.tokenized_words.apply(lambda x: [item for item in x if item.isalnum()])


#adds column for word count within stripped down sentences
script_df['word_count'] = [len(words) for words in script_df.alphanumeric_words ]
script_df
# Out:
#       release_date    season    episode     episode_title              name  \
# 0       2011-04-17  Season 1  Episode 1  Winter is Coming      waymar royce
# 1       2011-04-17  Season 1  Episode 1  Winter is Coming              will
# 2       2011-04-17  Season 1  Episode 1  Winter is Coming      waymar royce
# 3       2011-04-17  Season 1  Episode 1  Winter is Coming              will
# 4       2011-04-17  Season 1  Episode 1  Winter is Coming             gared
# ...            ...       ...        ...               ...               ...
# 23906   2019-05-19  Season 8  Episode 6   The Iron Throne           brienne
# 23907   2019-05-19  Season 8  Episode 6   The Iron Throne             bronn
# 23908   2019-05-19  Season 8  Episode 6   The Iron Throne  tyrion lannister
# 23909   2019-05-19  Season 8  Episode 6   The Iron Throne               man
# 23910   2019-05-19  Season 8  Episode 6   The Iron Throne               all
#
#                                                 sentence  positive_score  \
# 0      What do you expect? They're savages. One lot s...           0.000
# 1      I've never seen wildlings do a thing like this...           0.208
# 2                                 How close did you get?           0.000
# 3                                Close as any man would.           0.000
# 4                       We should head back to the wall.           0.000
# ...                                                  ...             ...
# 23906  I think we can all agree that ships take prece...           0.185
# 23907      I think that's a very presumptuous statement.           0.000
# 23908  I once brought a jackass and a honeycomb into ...           0.000
# 23909                            The Queen in the North!           0.000
# 23910  The Queen in the North! The Queen in the North...           0.000
#
#        compound_score  neutral_score  negative_score
# 0             -0.7717          0.774           0.226
# 1              0.6124          0.792           0.000
# 2              0.0000          1.000           0.000
# 3              0.0000          1.000           0.000
# 4              0.0000          1.000           0.000
# ...               ...            ...             ...
# 23906          0.3612          0.815           0.000
# 23907          0.0000          1.000           0.000
# 23908         -0.4215          0.781           0.219
# 23909          0.0000          1.000           0.000
# 23910          0.0000          1.000           0.000
#
# [23911 rows x 10 columns]

# %%
# converts df into dictionary and adds to mongodb

script_dict = script_df.to_dict('records')
script_dict
# Out:
# [{'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'waymar royce',
#   'sentence': "What do you expect? They're savages. One lot steals a goat from another lot and before you know it, they're ripping each other to pieces.",
#   'positive_score': 0.0,
#   'compound_score': -0.7717,
#   'neutral_score': 0.774,
#   'negative_score': 0.226,
#   'tokenized_words': ['What',
#    'do',
#    'you',
#    'expect',
#    '?',
#    'They',
#    "'re",
#    'savages',
#    '.',
#    'One',
#    'lot',
#    'steals',
#    'a',
#    'goat',
#    'from',
#    'another',
#    'lot',
#    'and',
#    'before',
#    'you',
#    'know',
#    'it',
#    ',',
#    'they',
#    "'re",
#    'ripping',
#    'each',
#    'other',
#    'to',
#    'pieces',
#    '.'],
#   'alphanumeric_words': ['What',
#    'do',
#    'you',
#    'expect',
#    'They',
#    'savages',
#    'One',
#    'lot',
#    'steals',
#    'a',
#    'goat',
#    'from',
#    'another',
#    'lot',
#    'and',
#    'before',
#    'you',
#    'know',
#    'it',
#    'they',
#    'ripping',
#    'each',
#    'other',
#    'to',
#    'pieces'],
#   'word_count': 25},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'will',
#   'sentence': "I've never seen wildlings do a thing like this. I've never seen a thing like this, not ever in my life.",
#   'positive_score': 0.208,
#   'compound_score': 0.6124,
#   'neutral_score': 0.792,
#   'negative_score': 0.0,
#   'tokenized_words': ['I',
#    "'ve",
#    'never',
#    'seen',
#    'wildlings',
#    'do',
#    'a',
#    'thing',
#    'like',
#    'this',
#    '.',
#    'I',
#    "'ve",
#    'never',
#    'seen',
#    'a',
#    'thing',
#    'like',
#    'this',
#    ',',
#    'not',
#    'ever',
#    'in',
#    'my',
#    'life',
#    '.'],
#   'alphanumeric_words': ['I',
#    'never',
#    'seen',
#    'wildlings',
#    'do',
#    'a',
#    'thing',
#    'like',
#    'this',
#    'I',
#    'never',
#    'seen',
#    'a',
#    'thing',
#    'like',
#    'this',
#    'not',
#    'ever',
#    'in',
#    'my',
#    'life'],
#   'word_count': 21},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'waymar royce',
#   'sentence': 'How close did you get?',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['How', 'close', 'did', 'you', 'get', '?'],
#   'alphanumeric_words': ['How', 'close', 'did', 'you', 'get'],
#   'word_count': 5},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'will',
#   'sentence': 'Close as any man would.',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['Close', 'as', 'any', 'man', 'would', '.'],
#   'alphanumeric_words': ['Close', 'as', 'any', 'man', 'would'],
#   'word_count': 5},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'gared',
#   'sentence': 'We should head back to the wall.',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['We',
#    'should',
#    'head',
#    'back',
#    'to',
#    'the',
#    'wall',
#    '.'],
#   'alphanumeric_words': ['We', 'should', 'head', 'back', 'to', 'the', 'wall'],
#   'word_count': 7},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'royce',
#   'sentence': 'Do the dead frighten you?',
#   'positive_score': 0.0,
#   'compound_score': -0.7717,
#   'neutral_score': 0.309,
#   'negative_score': 0.691,
#   'tokenized_words': ['Do', 'the', 'dead', 'frighten', 'you', '?'],
#   'alphanumeric_words': ['Do', 'the', 'dead', 'frighten', 'you'],
#   'word_count': 5},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'gared',
#   'sentence': "Our orders were to track the wildlings. We tracked them. They won't trouble us no more.",
#   'positive_score': 0.228,
#   'compound_score': 0.4847,
#   'neutral_score': 0.772,
#   'negative_score': 0.0,
#   'tokenized_words': ['Our',
#    'orders',
#    'were',
#    'to',
#    'track',
#    'the',
#    'wildlings',
#    '.',
#    'We',
#    'tracked',
#    'them',
#    '.',
#    'They',
#    'wo',
#    "n't",
#    'trouble',
#    'us',
#    'no',
#    'more',
#    '.'],
#   'alphanumeric_words': ['Our',
#    'orders',
#    'were',
#    'to',
#    'track',
#    'the',
#    'wildlings',
#    'We',
#    'tracked',
#    'them',
#    'They',
#    'wo',
#    'trouble',
#    'us',
#    'no',
#    'more'],
#   'word_count': 16},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'royce',
#   'sentence': "You don't think he'll ask us how they died? Get back on your horse.",
#   'positive_score': 0.0,
#   'compound_score': -0.5574,
#   'neutral_score': 0.783,
#   'negative_score': 0.217,
#   'tokenized_words': ['You',
#    'do',
#    "n't",
#    'think',
#    'he',
#    "'ll",
#    'ask',
#    'us',
#    'how',
#    'they',
#    'died',
#    '?',
#    'Get',
#    'back',
#    'on',
#    'your',
#    'horse',
#    '.'],
#   'alphanumeric_words': ['You',
#    'do',
#    'think',
#    'he',
#    'ask',
#    'us',
#    'how',
#    'they',
#    'died',
#    'Get',
#    'back',
#    'on',
#    'your',
#    'horse'],
#   'word_count': 14},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'will',
#   'sentence': 'Whatever did it to them could do it to us. They even killed the children.',
#   'positive_score': 0.0,
#   'compound_score': -0.6705,
#   'neutral_score': 0.757,
#   'negative_score': 0.243,
#   'tokenized_words': ['Whatever',
#    'did',
#    'it',
#    'to',
#    'them',
#    'could',
#    'do',
#    'it',
#    'to',
#    'us',
#    '.',
#    'They',
#    'even',
#    'killed',
#    'the',
#    'children',
#    '.'],
#   'alphanumeric_words': ['Whatever',
#    'did',
#    'it',
#    'to',
#    'them',
#    'could',
#    'do',
#    'it',
#    'to',
#    'us',
#    'They',
#    'even',
#    'killed',
#    'the',
#    'children'],
#   'word_count': 15},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'royce',
#   'sentence': "It's a good thing we're not children. You want to run away south, run away. Of course, they will behead you as a deserter … If I don't catch you first. Get back on your horse. I won't say it again.",
#   'positive_score': 0.067,
#   'compound_score': 0.3975,
#   'neutral_score': 0.904,
#   'negative_score': 0.028,
#   'tokenized_words': ['It',
#    "'s",
#    'a',
#    'good',
#    'thing',
#    'we',
#    "'re",
#    'not',
#    'children',
#    '.',
#    'You',
#    'want',
#    'to',
#    'run',
#    'away',
#    'south',
#    ',',
#    'run',
#    'away',
#    '.',
#    'Of',
#    'course',
#    ',',
#    'they',
#    'will',
#    'behead',
#    'you',
#    'as',
#    'a',
#    'deserter',
#    '…',
#    'If',
#    'I',
#    'do',
#    "n't",
#    'catch',
#    'you',
#    'first',
#    '.',
#    'Get',
#    'back',
#    'on',
#    'your',
#    'horse',
#    '.',
#    'I',
#    'wo',
#    "n't",
#    'say',
#    'it',
#    'again',
#    '.'],
#   'alphanumeric_words': ['It',
#    'a',
#    'good',
#    'thing',
#    'we',
#    'not',
#    'children',
#    'You',
#    'want',
#    'to',
#    'run',
#    'away',
#    'south',
#    'run',
#    'away',
#    'Of',
#    'course',
#    'they',
#    'will',
#    'behead',
#    'you',
#    'as',
#    'a',
#    'deserter',
#    'If',
#    'I',
#    'do',
#    'catch',
#    'you',
#    'first',
#    'Get',
#    'back',
#    'on',
#    'your',
#    'horse',
#    'I',
#    'wo',
#    'say',
#    'it',
#    'again'],
#   'word_count': 40},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'royce',
#   'sentence': 'Your dead men seem to have moved camp.',
#   'positive_score': 0.0,
#   'compound_score': -0.6486,
#   'neutral_score': 0.619,
#   'negative_score': 0.381,
#   'tokenized_words': ['Your',
#    'dead',
#    'men',
#    'seem',
#    'to',
#    'have',
#    'moved',
#    'camp',
#    '.'],
#   'alphanumeric_words': ['Your',
#    'dead',
#    'men',
#    'seem',
#    'to',
#    'have',
#    'moved',
#    'camp'],
#   'word_count': 8},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'will',
#   'sentence': 'They were here.',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['They', 'were', 'here', '.'],
#   'alphanumeric_words': ['They', 'were', 'here'],
#   'word_count': 3},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'gared',
#   'sentence': 'See where they went.',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['See', 'where', 'they', 'went', '.'],
#   'alphanumeric_words': ['See', 'where', 'they', 'went'],
#   'word_count': 4},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'royce',
#   'sentence': 'What is it?',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['What', 'is', 'it', '?'],
#   'alphanumeric_words': ['What', 'is', 'it'],
#   'word_count': 3},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'gared',
#   'sentence': "It's …",
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['It', "'s", '…'],
#   'alphanumeric_words': ['It'],
#   'word_count': 1},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'jon snow',
#   'sentence': "Go on. Father's watching.",
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['Go', 'on', '.', 'Father', "'s", 'watching', '.'],
#   'alphanumeric_words': ['Go', 'on', 'Father', 'watching'],
#   'word_count': 4},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'jon snow',
#   'sentence': 'And your mother.',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['And', 'your', 'mother', '.'],
#   'alphanumeric_words': ['And', 'your', 'mother'],
#   'word_count': 3},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'septa mordane',
#   'sentence': 'Fine work, as always. Well done.',
#   'positive_score': 0.494,
#   'compound_score': 0.4404,
#   'neutral_score': 0.506,
#   'negative_score': 0.0,
#   'tokenized_words': ['Fine',
#    'work',
#    ',',
#    'as',
#    'always',
#    '.',
#    'Well',
#    'done',
#    '.'],
#   'alphanumeric_words': ['Fine', 'work', 'as', 'always', 'Well', 'done'],
#   'word_count': 6},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'sansa stark',
#   'sentence': 'Thank you.',
#   'positive_score': 0.714,
#   'compound_score': 0.3612,
#   'neutral_score': 0.286,
#   'negative_score': 0.0,
#   'tokenized_words': ['Thank', 'you', '.'],
#   'alphanumeric_words': ['Thank', 'you'],
#   'word_count': 2},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'septa mordane',
#   'sentence': "I love the detail that you've managed to get in this corners. … Quite beautiful … the stitching …",
#   'positive_score': 0.331,
#   'compound_score': 0.8553,
#   'neutral_score': 0.669,
#   'negative_score': 0.0,
#   'tokenized_words': ['I',
#    'love',
#    'the',
#    'detail',
#    'that',
#    'you',
#    "'ve",
#    'managed',
#    'to',
#    'get',
#    'in',
#    'this',
#    'corners',
#    '.',
#    '…',
#    'Quite',
#    'beautiful',
#    '…',
#    'the',
#    'stitching',
#    '…'],
#   'alphanumeric_words': ['I',
#    'love',
#    'the',
#    'detail',
#    'that',
#    'you',
#    'managed',
#    'to',
#    'get',
#    'in',
#    'this',
#    'corners',
#    'Quite',
#    'beautiful',
#    'the',
#    'stitching'],
#   'word_count': 16},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'eddard stark',
#   'sentence': 'And which one of you was a marksman at ten? Keep practicing, Bran. Go on.',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['And',
#    'which',
#    'one',
#    'of',
#    'you',
#    'was',
#    'a',
#    'marksman',
#    'at',
#    'ten',
#    '?',
#    'Keep',
#    'practicing',
#    ',',
#    'Bran',
#    '.',
#    'Go',
#    'on',
#    '.'],
#   'alphanumeric_words': ['And',
#    'which',
#    'one',
#    'of',
#    'you',
#    'was',
#    'a',
#    'marksman',
#    'at',
#    'ten',
#    'Keep',
#    'practicing',
#    'Bran',
#    'Go',
#    'on'],
#   'word_count': 15},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'jon snow',
#   'sentence': "Don't think too much, Bran.",
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['Do', "n't", 'think', 'too', 'much', ',', 'Bran', '.'],
#   'alphanumeric_words': ['Do', 'think', 'too', 'much', 'Bran'],
#   'word_count': 5},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'robb stark',
#   'sentence': 'Relax your bow arm.',
#   'positive_score': 0.492,
#   'compound_score': 0.4404,
#   'neutral_score': 0.508,
#   'negative_score': 0.0,
#   'tokenized_words': ['Relax', 'your', 'bow', 'arm', '.'],
#   'alphanumeric_words': ['Relax', 'your', 'bow', 'arm'],
#   'word_count': 4},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'jonrobb',
#   'sentence': 'Quick, Bran, faster!',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['Quick', ',', 'Bran', ',', 'faster', '!'],
#   'alphanumeric_words': ['Quick', 'Bran', 'faster'],
#   'word_count': 3},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'cassel',
#   'sentence': "Lord Stark. My lady. A guardsman just rode in from the hills. They've captured a deserter from the Night's Watch.",
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['Lord',
#    'Stark',
#    '.',
#    'My',
#    'lady',
#    '.',
#    'A',
#    'guardsman',
#    'just',
#    'rode',
#    'in',
#    'from',
#    'the',
#    'hills',
#    '.',
#    'They',
#    "'ve",
#    'captured',
#    'a',
#    'deserter',
#    'from',
#    'the',
#    'Night',
#    "'s",
#    'Watch',
#    '.'],
#   'alphanumeric_words': ['Lord',
#    'Stark',
#    'My',
#    'lady',
#    'A',
#    'guardsman',
#    'just',
#    'rode',
#    'in',
#    'from',
#    'the',
#    'hills',
#    'They',
#    'captured',
#    'a',
#    'deserter',
#    'from',
#    'the',
#    'Night',
#    'Watch'],
#   'word_count': 20},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'eddard stark',
#   'sentence': 'Get the lads to saddle their horses.',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['Get',
#    'the',
#    'lads',
#    'to',
#    'saddle',
#    'their',
#    'horses',
#    '.'],
#   'alphanumeric_words': ['Get',
#    'the',
#    'lads',
#    'to',
#    'saddle',
#    'their',
#    'horses'],
#   'word_count': 7},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'catelyn stark',
#   'sentence': 'Do you have to?',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['Do', 'you', 'have', 'to', '?'],
#   'alphanumeric_words': ['Do', 'you', 'have', 'to'],
#   'word_count': 4},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'eddard stark',
#   'sentence': 'He swore an oath, Cat.',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['He', 'swore', 'an', 'oath', ',', 'Cat', '.'],
#   'alphanumeric_words': ['He', 'swore', 'an', 'oath', 'Cat'],
#   'word_count': 5},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'cassel',
#   'sentence': 'The law is law, my lady.',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['The', 'law', 'is', 'law', ',', 'my', 'lady', '.'],
#   'alphanumeric_words': ['The', 'law', 'is', 'law', 'my', 'lady'],
#   'word_count': 6},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'eddard stark',
#   'sentence': "Tell Bran he's coming, too.",
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['Tell', 'Bran', 'he', "'s", 'coming', ',', 'too', '.'],
#   'alphanumeric_words': ['Tell', 'Bran', 'he', 'coming', 'too'],
#   'word_count': 5},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'catelyn stark',
#   'sentence': 'Ned. Ten is too young to see such things.',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['Ned',
#    '.',
#    'Ten',
#    'is',
#    'too',
#    'young',
#    'to',
#    'see',
#    'such',
#    'things',
#    '.'],
#   'alphanumeric_words': ['Ned',
#    'Ten',
#    'is',
#    'too',
#    'young',
#    'to',
#    'see',
#    'such',
#    'things'],
#   'word_count': 9},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'eddard stark',
#   'sentence': "He won't be a boy forever. And winter is coming.",
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['He',
#    'wo',
#    "n't",
#    'be',
#    'a',
#    'boy',
#    'forever',
#    '.',
#    'And',
#    'winter',
#    'is',
#    'coming',
#    '.'],
#   'alphanumeric_words': ['He',
#    'wo',
#    'be',
#    'a',
#    'boy',
#    'forever',
#    'And',
#    'winter',
#    'is',
#    'coming'],
#   'word_count': 10},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'robb stark',
#   'sentence': 'Lad, go run back and get the rest.',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['Lad',
#    ',',
#    'go',
#    'run',
#    'back',
#    'and',
#    'get',
#    'the',
#    'rest',
#    '.'],
#   'alphanumeric_words': ['Lad',
#    'go',
#    'run',
#    'back',
#    'and',
#    'get',
#    'the',
#    'rest'],
#   'word_count': 8},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'will',
#   'sentence': 'White Walkers. I saw the White Walkers. White Walkers. The White Walkers, I saw them.',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['White',
#    'Walkers',
#    '.',
#    'I',
#    'saw',
#    'the',
#    'White',
#    'Walkers',
#    '.',
#    'White',
#    'Walkers',
#    '.',
#    'The',
#    'White',
#    'Walkers',
#    ',',
#    'I',
#    'saw',
#    'them',
#    '.'],
#   'alphanumeric_words': ['White',
#    'Walkers',
#    'I',
#    'saw',
#    'the',
#    'White',
#    'Walkers',
#    'White',
#    'Walkers',
#    'The',
#    'White',
#    'Walkers',
#    'I',
#    'saw',
#    'them'],
#   'word_count': 15},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'will',
#   'sentence': "I know I broke my oath. And I know I'm a deserter. I should have gone back to the Wall and warned them. But I saw what I saw. I saw the White Walkers. People need to know. If you can get word to my family, tell them I'm no coward. Tell them I'm sorry.",
#   'positive_score': 0.054,
#   'compound_score': 0.0823,
#   'neutral_score': 0.863,
#   'negative_score': 0.083,
#   'tokenized_words': ['I',
#    'know',
#    'I',
#    'broke',
#    'my',
#    'oath',
#    '.',
#    'And',
#    'I',
#    'know',
#    'I',
#    "'m",
#    'a',
#    'deserter',
#    '.',
#    'I',
#    'should',
#    'have',
#    'gone',
#    'back',
#    'to',
#    'the',
#    'Wall',
#    'and',
#    'warned',
#    'them',
#    '.',
#    'But',
#    'I',
#    'saw',
#    'what',
#    'I',
#    'saw',
#    '.',
#    'I',
#    'saw',
#    'the',
#    'White',
#    'Walkers',
#    '.',
#    'People',
#    'need',
#    'to',
#    'know',
#    '.',
#    'If',
#    'you',
#    'can',
#    'get',
#    'word',
#    'to',
#    'my',
#    'family',
#    ',',
#    'tell',
#    'them',
#    'I',
#    "'m",
#    'no',
#    'coward',
#    '.',
#    'Tell',
#    'them',
#    'I',
#    "'m",
#    'sorry',
#    '.'],
#   'alphanumeric_words': ['I',
#    'know',
#    'I',
#    'broke',
#    'my',
#    'oath',
#    'And',
#    'I',
#    'know',
#    'I',
#    'a',
#    'deserter',
#    'I',
#    'should',
#    'have',
#    'gone',
#    'back',
#    'to',
#    'the',
#    'Wall',
#    'and',
#    'warned',
#    'them',
#    'But',
#    'I',
#    'saw',
#    'what',
#    'I',
#    'saw',
#    'I',
#    'saw',
#    'the',
#    'White',
#    'Walkers',
#    'People',
#    'need',
#    'to',
#    'know',
#    'If',
#    'you',
#    'can',
#    'get',
#    'word',
#    'to',
#    'my',
#    'family',
#    'tell',
#    'them',
#    'I',
#    'no',
#    'coward',
#    'Tell',
#    'them',
#    'I',
#    'sorry'],
#   'word_count': 55},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'eddard stark',
#   'sentence': 'nods yes, and WILL is positioned on the tree limb that serves as a block.',
#   'positive_score': 0.145,
#   'compound_score': -0.0516,
#   'neutral_score': 0.699,
#   'negative_score': 0.156,
#   'tokenized_words': ['nods',
#    'yes',
#    ',',
#    'and',
#    'WILL',
#    'is',
#    'positioned',
#    'on',
#    'the',
#    'tree',
#    'limb',
#    'that',
#    'serves',
#    'as',
#    'a',
#    'block',
#    '.'],
#   'alphanumeric_words': ['nods',
#    'yes',
#    'and',
#    'WILL',
#    'is',
#    'positioned',
#    'on',
#    'the',
#    'tree',
#    'limb',
#    'that',
#    'serves',
#    'as',
#    'a',
#    'block'],
#   'word_count': 15},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'will',
#   'sentence': 'Forgive me, lord.',
#   'positive_score': 0.512,
#   'compound_score': 0.2732,
#   'neutral_score': 0.488,
#   'negative_score': 0.0,
#   'tokenized_words': ['Forgive', 'me', ',', 'lord', '.'],
#   'alphanumeric_words': ['Forgive', 'me', 'lord'],
#   'word_count': 3},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'eddard stark',
#   'sentence': 'In the name of Robert of the House Baratheon, first of his name …',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['In',
#    'the',
#    'name',
#    'of',
#    'Robert',
#    'of',
#    'the',
#    'House',
#    'Baratheon',
#    ',',
#    'first',
#    'of',
#    'his',
#    'name',
#    '…'],
#   'alphanumeric_words': ['In',
#    'the',
#    'name',
#    'of',
#    'Robert',
#    'of',
#    'the',
#    'House',
#    'Baratheon',
#    'first',
#    'of',
#    'his',
#    'name'],
#   'word_count': 13},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'jon snow',
#   'sentence': "Don't look away.",
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['Do', "n't", 'look', 'away', '.'],
#   'alphanumeric_words': ['Do', 'look', 'away'],
#   'word_count': 3},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'eddard stark',
#   'sentence': 'King of the Andals and the First Men …',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['King',
#    'of',
#    'the',
#    'Andals',
#    'and',
#    'the',
#    'First',
#    'Men',
#    '…'],
#   'alphanumeric_words': ['King',
#    'of',
#    'the',
#    'Andals',
#    'and',
#    'the',
#    'First',
#    'Men'],
#   'word_count': 8},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'jon snow',
#   'sentence': 'Father will know if you do.',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['Father', 'will', 'know', 'if', 'you', 'do', '.'],
#   'alphanumeric_words': ['Father', 'will', 'know', 'if', 'you', 'do'],
#   'word_count': 6},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'eddard stark',
#   'sentence': 'Lord of the Seven Kingdoms and protector of the realm, I, Eddard of the House Stark, Lord of Winterfell and Warden of the North, sentence you to die.',
#   'positive_score': 0.042,
#   'compound_score': -0.5574,
#   'neutral_score': 0.833,
#   'negative_score': 0.125,
#   'tokenized_words': ['Lord',
#    'of',
#    'the',
#    'Seven',
#    'Kingdoms',
#    'and',
#    'protector',
#    'of',
#    'the',
#    'realm',
#    ',',
#    'I',
#    ',',
#    'Eddard',
#    'of',
#    'the',
#    'House',
#    'Stark',
#    ',',
#    'Lord',
#    'of',
#    'Winterfell',
#    'and',
#    'Warden',
#    'of',
#    'the',
#    'North',
#    ',',
#    'sentence',
#    'you',
#    'to',
#    'die',
#    '.'],
#   'alphanumeric_words': ['Lord',
#    'of',
#    'the',
#    'Seven',
#    'Kingdoms',
#    'and',
#    'protector',
#    'of',
#    'the',
#    'realm',
#    'I',
#    'Eddard',
#    'of',
#    'the',
#    'House',
#    'Stark',
#    'Lord',
#    'of',
#    'Winterfell',
#    'and',
#    'Warden',
#    'of',
#    'the',
#    'North',
#    'sentence',
#    'you',
#    'to',
#    'die'],
#   'word_count': 28},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'jon snow',
#   'sentence': 'You did well.',
#   'positive_score': 0.512,
#   'compound_score': 0.2732,
#   'neutral_score': 0.488,
#   'negative_score': 0.0,
#   'tokenized_words': ['You', 'did', 'well', '.'],
#   'alphanumeric_words': ['You', 'did', 'well'],
#   'word_count': 3},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'eddard stark',
#   'sentence': 'You understand why I did it?',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['You', 'understand', 'why', 'I', 'did', 'it', '?'],
#   'alphanumeric_words': ['You', 'understand', 'why', 'I', 'did', 'it'],
#   'word_count': 6},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'bran stark',
#   'sentence': 'Jon said he was a deserter.',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['Jon', 'said', 'he', 'was', 'a', 'deserter', '.'],
#   'alphanumeric_words': ['Jon', 'said', 'he', 'was', 'a', 'deserter'],
#   'word_count': 6},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'eddard stark',
#   'sentence': 'But do you understand why I had to kill him?',
#   'positive_score': 0.0,
#   'compound_score': -0.8201,
#   'neutral_score': 0.579,
#   'negative_score': 0.421,
#   'tokenized_words': ['But',
#    'do',
#    'you',
#    'understand',
#    'why',
#    'I',
#    'had',
#    'to',
#    'kill',
#    'him',
#    '?'],
#   'alphanumeric_words': ['But',
#    'do',
#    'you',
#    'understand',
#    'why',
#    'I',
#    'had',
#    'to',
#    'kill',
#    'him'],
#   'word_count': 10},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'bran stark',
#   'sentence': 'Our way is the old way?',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['Our', 'way', 'is', 'the', 'old', 'way', '?'],
#   'alphanumeric_words': ['Our', 'way', 'is', 'the', 'old', 'way'],
#   'word_count': 6},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'eddard stark',
#   'sentence': 'The man who passes the sentence should swing the sword.',
#   'positive_score': 0.126,
#   'compound_score': 0.0772,
#   'neutral_score': 0.874,
#   'negative_score': 0.0,
#   'tokenized_words': ['The',
#    'man',
#    'who',
#    'passes',
#    'the',
#    'sentence',
#    'should',
#    'swing',
#    'the',
#    'sword',
#    '.'],
#   'alphanumeric_words': ['The',
#    'man',
#    'who',
#    'passes',
#    'the',
#    'sentence',
#    'should',
#    'swing',
#    'the',
#    'sword'],
#   'word_count': 10},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'bran stark',
#   'sentence': 'Is it true he saw the White Walkers?',
#   'positive_score': 0.286,
#   'compound_score': 0.4215,
#   'neutral_score': 0.714,
#   'negative_score': 0.0,
#   'tokenized_words': ['Is',
#    'it',
#    'true',
#    'he',
#    'saw',
#    'the',
#    'White',
#    'Walkers',
#    '?'],
#   'alphanumeric_words': ['Is',
#    'it',
#    'true',
#    'he',
#    'saw',
#    'the',
#    'White',
#    'Walkers'],
#   'word_count': 8},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'eddard stark',
#   'sentence': 'The White Walkers have been gone for thousands of years.',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['The',
#    'White',
#    'Walkers',
#    'have',
#    'been',
#    'gone',
#    'for',
#    'thousands',
#    'of',
#    'years',
#    '.'],
#   'alphanumeric_words': ['The',
#    'White',
#    'Walkers',
#    'have',
#    'been',
#    'gone',
#    'for',
#    'thousands',
#    'of',
#    'years'],
#   'word_count': 10},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'bran stark',
#   'sentence': 'So he was lying?',
#   'positive_score': 0.0,
#   'compound_score': -0.5667,
#   'neutral_score': 0.45,
#   'negative_score': 0.55,
#   'tokenized_words': ['So', 'he', 'was', 'lying', '?'],
#   'alphanumeric_words': ['So', 'he', 'was', 'lying'],
#   'word_count': 4},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'eddard stark',
#   'sentence': 'A madman sees what he sees.',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['A', 'madman', 'sees', 'what', 'he', 'sees', '.'],
#   'alphanumeric_words': ['A', 'madman', 'sees', 'what', 'he', 'sees'],
#   'word_count': 6},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'jon snow',
#   'sentence': 'What is it?',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['What', 'is', 'it', '?'],
#   'alphanumeric_words': ['What', 'is', 'it'],
#   'word_count': 3},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'theon greyjoy',
#   'sentence': 'Mountain lion?',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['Mountain', 'lion', '?'],
#   'alphanumeric_words': ['Mountain', 'lion'],
#   'word_count': 2},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'eddard stark',
#   'sentence': 'There are no mountain lions in these woods.',
#   'positive_score': 0.0,
#   'compound_score': -0.296,
#   'neutral_score': 0.761,
#   'negative_score': 0.239,
#   'tokenized_words': ['There',
#    'are',
#    'no',
#    'mountain',
#    'lions',
#    'in',
#    'these',
#    'woods',
#    '.'],
#   'alphanumeric_words': ['There',
#    'are',
#    'no',
#    'mountain',
#    'lions',
#    'in',
#    'these',
#    'woods'],
#   'word_count': 8},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'theon greyjoy',
#   'sentence': "It's a freak.",
#   'positive_score': 0.0,
#   'compound_score': -0.4404,
#   'neutral_score': 0.408,
#   'negative_score': 0.592,
#   'tokenized_words': ['It', "'s", 'a', 'freak', '.'],
#   'alphanumeric_words': ['It', 'a', 'freak'],
#   'word_count': 3},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'eddard stark',
#   'sentence': "It's a direwolf.",
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['It', "'s", 'a', 'direwolf', '.'],
#   'alphanumeric_words': ['It', 'a', 'direwolf'],
#   'word_count': 3},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'eddard stark',
#   'sentence': 'Tough old beast.',
#   'positive_score': 0.0,
#   'compound_score': -0.128,
#   'neutral_score': 0.571,
#   'negative_score': 0.429,
#   'tokenized_words': ['Tough', 'old', 'beast', '.'],
#   'alphanumeric_words': ['Tough', 'old', 'beast'],
#   'word_count': 3},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'robb stark',
#   'sentence': 'There are no direwolves south of the Wall.',
#   'positive_score': 0.0,
#   'compound_score': -0.296,
#   'neutral_score': 0.761,
#   'negative_score': 0.239,
#   'tokenized_words': ['There',
#    'are',
#    'no',
#    'direwolves',
#    'south',
#    'of',
#    'the',
#    'Wall',
#    '.'],
#   'alphanumeric_words': ['There',
#    'are',
#    'no',
#    'direwolves',
#    'south',
#    'of',
#    'the',
#    'Wall'],
#   'word_count': 8},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'jon snow',
#   'sentence': 'Now there are five.',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['Now', 'there', 'are', 'five', '.'],
#   'alphanumeric_words': ['Now', 'there', 'are', 'five'],
#   'word_count': 4},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'jon snow',
#   'sentence': 'You want to hold it?',
#   'positive_score': 0.245,
#   'compound_score': 0.0772,
#   'neutral_score': 0.755,
#   'negative_score': 0.0,
#   'tokenized_words': ['You', 'want', 'to', 'hold', 'it', '?'],
#   'alphanumeric_words': ['You', 'want', 'to', 'hold', 'it'],
#   'word_count': 5},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'bran stark',
#   'sentence': "Where will they go? Their mother's dead.",
#   'positive_score': 0.0,
#   'compound_score': -0.6486,
#   'neutral_score': 0.583,
#   'negative_score': 0.417,
#   'tokenized_words': ['Where',
#    'will',
#    'they',
#    'go',
#    '?',
#    'Their',
#    'mother',
#    "'s",
#    'dead',
#    '.'],
#   'alphanumeric_words': ['Where',
#    'will',
#    'they',
#    'go',
#    'Their',
#    'mother',
#    'dead'],
#   'word_count': 7},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'cassel',
#   'sentence': "They don't belong down here.",
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['They', 'do', "n't", 'belong', 'down', 'here', '.'],
#   'alphanumeric_words': ['They', 'do', 'belong', 'down', 'here'],
#   'word_count': 5},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'eddard stark',
#   'sentence': "Better a quick death. They won't last without their mother.",
#   'positive_score': 0.196,
#   'compound_score': -0.25,
#   'neutral_score': 0.541,
#   'negative_score': 0.264,
#   'tokenized_words': ['Better',
#    'a',
#    'quick',
#    'death',
#    '.',
#    'They',
#    'wo',
#    "n't",
#    'last',
#    'without',
#    'their',
#    'mother',
#    '.'],
#   'alphanumeric_words': ['Better',
#    'a',
#    'quick',
#    'death',
#    'They',
#    'wo',
#    'last',
#    'without',
#    'their',
#    'mother'],
#   'word_count': 10},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'theon greyjoy',
#   'sentence': 'Right. Give it here.',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['Right', '.', 'Give', 'it', 'here', '.'],
#   'alphanumeric_words': ['Right', 'Give', 'it', 'here'],
#   'word_count': 4},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'bran stark',
#   'sentence': 'NO!',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['NO', '!'],
#   'alphanumeric_words': ['NO'],
#   'word_count': 1},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'robb stark',
#   'sentence': 'Put away your blade.',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['Put', 'away', 'your', 'blade', '.'],
#   'alphanumeric_words': ['Put', 'away', 'your', 'blade'],
#   'word_count': 4},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'theon greyjoy',
#   'sentence': 'I take orders from your father, not you.',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['I',
#    'take',
#    'orders',
#    'from',
#    'your',
#    'father',
#    ',',
#    'not',
#    'you',
#    '.'],
#   'alphanumeric_words': ['I',
#    'take',
#    'orders',
#    'from',
#    'your',
#    'father',
#    'not',
#    'you'],
#   'word_count': 8},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'bran stark',
#   'sentence': 'Please, father!',
#   'positive_score': 0.722,
#   'compound_score': 0.3802,
#   'neutral_score': 0.278,
#   'negative_score': 0.0,
#   'tokenized_words': ['Please', ',', 'father', '!'],
#   'alphanumeric_words': ['Please', 'father'],
#   'word_count': 2},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'eddard stark',
#   'sentence': "I'm sorry, Bran.",
#   'positive_score': 0.0,
#   'compound_score': -0.0772,
#   'neutral_score': 0.606,
#   'negative_score': 0.394,
#   'tokenized_words': ['I', "'m", 'sorry', ',', 'Bran', '.'],
#   'alphanumeric_words': ['I', 'sorry', 'Bran'],
#   'word_count': 3},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'jon snow',
#   'sentence': 'Lord Stark? There are five pups. One for each of the Stark children. The direwolf is the sigil of your House. They were meant to have them.',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['Lord',
#    'Stark',
#    '?',
#    'There',
#    'are',
#    'five',
#    'pups',
#    '.',
#    'One',
#    'for',
#    'each',
#    'of',
#    'the',
#    'Stark',
#    'children',
#    '.',
#    'The',
#    'direwolf',
#    'is',
#    'the',
#    'sigil',
#    'of',
#    'your',
#    'House',
#    '.',
#    'They',
#    'were',
#    'meant',
#    'to',
#    'have',
#    'them',
#    '.'],
#   'alphanumeric_words': ['Lord',
#    'Stark',
#    'There',
#    'are',
#    'five',
#    'pups',
#    'One',
#    'for',
#    'each',
#    'of',
#    'the',
#    'Stark',
#    'children',
#    'The',
#    'direwolf',
#    'is',
#    'the',
#    'sigil',
#    'of',
#    'your',
#    'House',
#    'They',
#    'were',
#    'meant',
#    'to',
#    'have',
#    'them'],
#   'word_count': 27},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'eddard stark',
#   'sentence': 'You will train them yourselves. You will feed them yourselves. And if they die, you will bury them yourselves.',
#   'positive_score': 0.0,
#   'compound_score': -0.5994,
#   'neutral_score': 0.822,
#   'negative_score': 0.178,
#   'tokenized_words': ['You',
#    'will',
#    'train',
#    'them',
#    'yourselves',
#    '.',
#    'You',
#    'will',
#    'feed',
#    'them',
#    'yourselves',
#    '.',
#    'And',
#    'if',
#    'they',
#    'die',
#    ',',
#    'you',
#    'will',
#    'bury',
#    'them',
#    'yourselves',
#    '.'],
#   'alphanumeric_words': ['You',
#    'will',
#    'train',
#    'them',
#    'yourselves',
#    'You',
#    'will',
#    'feed',
#    'them',
#    'yourselves',
#    'And',
#    'if',
#    'they',
#    'die',
#    'you',
#    'will',
#    'bury',
#    'them',
#    'yourselves'],
#   'word_count': 19},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'bran stark',
#   'sentence': 'What about you?',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['What', 'about', 'you', '?'],
#   'alphanumeric_words': ['What', 'about', 'you'],
#   'word_count': 3},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'jon snow',
#   'sentence': "I'm not a Stark. Get on.",
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['I', "'m", 'not', 'a', 'Stark', '.', 'Get', 'on', '.'],
#   'alphanumeric_words': ['I', 'not', 'a', 'Stark', 'Get', 'on'],
#   'word_count': 6},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'robb stark',
#   'sentence': 'What is it?',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['What', 'is', 'it', '?'],
#   'alphanumeric_words': ['What', 'is', 'it'],
#   'word_count': 3},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'theon greyjoy',
#   'sentence': "The runt of the litter. That one's yours, Snow.",
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['The',
#    'runt',
#    'of',
#    'the',
#    'litter',
#    '.',
#    'That',
#    'one',
#    "'s",
#    'yours',
#    ',',
#    'Snow',
#    '.'],
#   'alphanumeric_words': ['The',
#    'runt',
#    'of',
#    'the',
#    'litter',
#    'That',
#    'one',
#    'yours',
#    'Snow'],
#   'word_count': 9},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'jaime lannister',
#   'sentence': "As your brother, I feel it's my duty to warn you",
#   'positive_score': 0.0,
#   'compound_score': -0.1027,
#   'neutral_score': 0.877,
#   'negative_score': 0.123,
#   'tokenized_words': ['As',
#    'your',
#    'brother',
#    ',',
#    'I',
#    'feel',
#    'it',
#    "'s",
#    'my',
#    'duty',
#    'to',
#    'warn',
#    'you'],
#   'alphanumeric_words': ['As',
#    'your',
#    'brother',
#    'I',
#    'feel',
#    'it',
#    'my',
#    'duty',
#    'to',
#    'warn',
#    'you'],
#   'word_count': 11},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'cersei lannister',
#   'sentence': 'And you never worry about anything. When we were seven, you jumped off the cliffs as Casterly Rock. One hundred foot drop into the water. And you were never afraid.',
#   'positive_score': 0.074,
#   'compound_score': 0.0788,
#   'neutral_score': 0.861,
#   'negative_score': 0.065,
#   'tokenized_words': ['And',
#    'you',
#    'never',
#    'worry',
#    'about',
#    'anything',
#    '.',
#    'When',
#    'we',
#    'were',
#    'seven',
#    ',',
#    'you',
#    'jumped',
#    'off',
#    'the',
#    'cliffs',
#    'as',
#    'Casterly',
#    'Rock',
#    '.',
#    'One',
#    'hundred',
#    'foot',
#    'drop',
#    'into',
#    'the',
#    'water',
#    '.',
#    'And',
#    'you',
#    'were',
#    'never',
#    'afraid',
#    '.'],
#   'alphanumeric_words': ['And',
#    'you',
#    'never',
#    'worry',
#    'about',
#    'anything',
#    'When',
#    'we',
#    'were',
#    'seven',
#    'you',
#    'jumped',
#    'off',
#    'the',
#    'cliffs',
#    'as',
#    'Casterly',
#    'Rock',
#    'One',
#    'hundred',
#    'foot',
#    'drop',
#    'into',
#    'the',
#    'water',
#    'And',
#    'you',
#    'were',
#    'never',
#    'afraid'],
#   'word_count': 30},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'jaime lannister',
#   'sentence': "There was nothing to be afraid of until you told father. [In a whisper, mimicking] We're Lannisters. Lannisters don't act like fools.",
#   'positive_score': 0.106,
#   'compound_score': 0.1326,
#   'neutral_score': 0.808,
#   'negative_score': 0.085,
#   'tokenized_words': ['There',
#    'was',
#    'nothing',
#    'to',
#    'be',
#    'afraid',
#    'of',
#    'until',
#    'you',
#    'told',
#    'father',
#    '.',
#    '[',
#    'In',
#    'a',
#    'whisper',
#    ',',
#    'mimicking',
#    ']',
#    'We',
#    "'re",
#    'Lannisters',
#    '.',
#    'Lannisters',
#    'do',
#    "n't",
#    'act',
#    'like',
#    'fools',
#    '.'],
#   'alphanumeric_words': ['There',
#    'was',
#    'nothing',
#    'to',
#    'be',
#    'afraid',
#    'of',
#    'until',
#    'you',
#    'told',
#    'father',
#    'In',
#    'a',
#    'whisper',
#    'mimicking',
#    'We',
#    'Lannisters',
#    'Lannisters',
#    'do',
#    'act',
#    'like',
#    'fools'],
#   'word_count': 22},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'cersei lannister',
#   'sentence': 'What if Jon Arryn told someone?',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['What', 'if', 'Jon', 'Arryn', 'told', 'someone', '?'],
#   'alphanumeric_words': ['What', 'if', 'Jon', 'Arryn', 'told', 'someone'],
#   'word_count': 6},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'jaime lannister',
#   'sentence': 'But who would he tell?',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['But', 'who', 'would', 'he', 'tell', '?'],
#   'alphanumeric_words': ['But', 'who', 'would', 'he', 'tell'],
#   'word_count': 5},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'cersei lannister',
#   'sentence': 'My husband.',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['My', 'husband', '.'],
#   'alphanumeric_words': ['My', 'husband'],
#   'word_count': 2},
#  {'release_date': '2011-04-17',
#   'season': 'Season 1',
#   'episode': 'Episode 1',
#   'episode_title': 'Winter is Coming',
#   'name': 'jaime lannister',
#   'sentence': "If he told the king, both our heads would be skewered on the city gates by now. Whatever Jon Arryn knew or didn't know, it died with him. And Robert will choose a new Hand of the king, someone to do his job while he's off fucking boars and hunting whores. Or is it the other way around? And life will go on.",
#   'positive_score': 0.087,
#   'compound_score': 0.2787,
#   'neutral_score': 0.856,
# ...
#    'so',
#    'kind',
#    'as',
#    'to',
#    'kneel',
#    '?',
#    'My',
#    'neck',
#    'is',
#    'beginning',
#    'to',
#    'hurt',
#    '.'],
#   'alphanumeric_words': ['Would',
#    'your',
#    'charming',
#    'companion',
#    'be',
#    'so',
#    'kind',
#    'as',
#    'to',
#    'kneel',
#    'My',
#    'neck',
#    'is',
#    'beginning',
#    'to',
#    'hurt'],
#   'word_count': 16},
#  {'release_date': '2011-05-08',
#   'season': 'Season 1',
#   'episode': 'Episode 4',
#   'episode_title': 'Cripples, Bastards and Broken Things',
#   'name': 'bran stark',
#   'sentence': 'Kneel, Hodor.',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['Kneel', ',', 'Hodor', '.'],
#   'alphanumeric_words': ['Kneel', 'Hodor'],
#   'word_count': 2},
#  {'release_date': '2011-05-08',
#   'season': 'Season 1',
#   'episode': 'Episode 4',
#   'episode_title': 'Cripples, Bastards and Broken Things',
#   'name': 'tyrion lannister',
#   'sentence': 'Do you like to ride, Bran?',
#   'positive_score': 0.333,
#   'compound_score': 0.3612,
#   'neutral_score': 0.667,
#   'negative_score': 0.0,
#   'tokenized_words': ['Do', 'you', 'like', 'to', 'ride', ',', 'Bran', '?'],
#   'alphanumeric_words': ['Do', 'you', 'like', 'to', 'ride', 'Bran'],
#   'word_count': 6},
#  {'release_date': '2011-05-08',
#   'season': 'Season 1',
#   'episode': 'Episode 4',
#   'episode_title': 'Cripples, Bastards and Broken Things',
#   'name': 'bran stark',
#   'sentence': 'Yes. Well, I mean I did like to.',
#   'positive_score': 0.593,
#   'compound_score': 0.743,
#   'neutral_score': 0.407,
#   'negative_score': 0.0,
#   'tokenized_words': ['Yes',
#    '.',
#    'Well',
#    ',',
#    'I',
#    'mean',
#    'I',
#    'did',
#    'like',
#    'to',
#    '.'],
#   'alphanumeric_words': ['Yes', 'Well', 'I', 'mean', 'I', 'did', 'like', 'to'],
#   'word_count': 8},
#  {'release_date': '2011-05-08',
#   'season': 'Season 1',
#   'episode': 'Episode 4',
#   'episode_title': 'Cripples, Bastards and Broken Things',
#   'name': 'maester luwin',
#   'sentence': 'The boy has lost the use of his legs.',
#   'positive_score': 0.0,
#   'compound_score': -0.3182,
#   'neutral_score': 0.777,
#   'negative_score': 0.223,
#   'tokenized_words': ['The',
#    'boy',
#    'has',
#    'lost',
#    'the',
#    'use',
#    'of',
#    'his',
#    'legs',
#    '.'],
#   'alphanumeric_words': ['The',
#    'boy',
#    'has',
#    'lost',
#    'the',
#    'use',
#    'of',
#    'his',
#    'legs'],
#   'word_count': 9},
#  {'release_date': '2011-05-08',
#   'season': 'Season 1',
#   'episode': 'Episode 4',
#   'episode_title': 'Cripples, Bastards and Broken Things',
#   'name': 'tyrion lannister',
#   'sentence': 'What of it? With the right horse and saddle, even a cripple can ride.',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['What',
#    'of',
#    'it',
#    '?',
#    'With',
#    'the',
#    'right',
#    'horse',
#    'and',
#    'saddle',
#    ',',
#    'even',
#    'a',
#    'cripple',
#    'can',
#    'ride',
#    '.'],
#   'alphanumeric_words': ['What',
#    'of',
#    'it',
#    'With',
#    'the',
#    'right',
#    'horse',
#    'and',
#    'saddle',
#    'even',
#    'a',
#    'cripple',
#    'can',
#    'ride'],
#   'word_count': 14},
#  {'release_date': '2011-05-08',
#   'season': 'Season 1',
#   'episode': 'Episode 4',
#   'episode_title': 'Cripples, Bastards and Broken Things',
#   'name': 'bran stark',
#   'sentence': "I'm not a cripple.",
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['I', "'m", 'not', 'a', 'cripple', '.'],
#   'alphanumeric_words': ['I', 'not', 'a', 'cripple'],
#   'word_count': 4},
#  {'release_date': '2011-05-08',
#   'season': 'Season 1',
#   'episode': 'Episode 4',
#   'episode_title': 'Cripples, Bastards and Broken Things',
#   'name': 'tyrion lannister',
#   'sentence': "Then I'm not a dwarf. My father will rejoice to hear it. I have a gift for you. Give that to your saddler. He'll provide the rest. You must shape the horse to the rider. Start with a yearling and teach it to respond to the reins and to the boy's voice.",
#   'positive_score': 0.104,
#   'compound_score': 0.7003,
#   'neutral_score': 0.896,
#   'negative_score': 0.0,
#   'tokenized_words': ['Then',
#    'I',
#    "'m",
#    'not',
#    'a',
#    'dwarf',
#    '.',
#    'My',
#    'father',
#    'will',
#    'rejoice',
#    'to',
#    'hear',
#    'it',
#    '.',
#    'I',
#    'have',
#    'a',
#    'gift',
#    'for',
#    'you',
#    '.',
#    'Give',
#    'that',
#    'to',
#    'your',
#    'saddler',
#    '.',
#    'He',
#    "'ll",
#    'provide',
#    'the',
#    'rest',
#    '.',
#    'You',
#    'must',
#    'shape',
#    'the',
#    'horse',
#    'to',
#    'the',
#    'rider',
#    '.',
#    'Start',
#    'with',
#    'a',
#    'yearling',
#    'and',
#    'teach',
#    'it',
#    'to',
#    'respond',
#    'to',
#    'the',
#    'reins',
#    'and',
#    'to',
#    'the',
#    'boy',
#    "'s",
#    'voice',
#    '.'],
#   'alphanumeric_words': ['Then',
#    'I',
#    'not',
#    'a',
#    'dwarf',
#    'My',
#    'father',
#    'will',
#    'rejoice',
#    'to',
#    'hear',
#    'it',
#    'I',
#    'have',
#    'a',
#    'gift',
#    'for',
#    'you',
#    'Give',
#    'that',
#    'to',
#    'your',
#    'saddler',
#    'He',
#    'provide',
#    'the',
#    'rest',
#    'You',
#    'must',
#    'shape',
#    'the',
#    'horse',
#    'to',
#    'the',
#    'rider',
#    'Start',
#    'with',
#    'a',
#    'yearling',
#    'and',
#    'teach',
#    'it',
#    'to',
#    'respond',
#    'to',
#    'the',
#    'reins',
#    'and',
#    'to',
#    'the',
#    'boy',
#    'voice'],
#   'word_count': 52},
#  {'release_date': '2011-05-08',
#   'season': 'Season 1',
#   'episode': 'Episode 4',
#   'episode_title': 'Cripples, Bastards and Broken Things',
#   'name': 'bran stark',
#   'sentence': 'Will I really be able to ride?',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['Will', 'I', 'really', 'be', 'able', 'to', 'ride', '?'],
#   'alphanumeric_words': ['Will', 'I', 'really', 'be', 'able', 'to', 'ride'],
#   'word_count': 7},
#  {'release_date': '2011-05-08',
#   'season': 'Season 1',
#   'episode': 'Episode 4',
#   'episode_title': 'Cripples, Bastards and Broken Things',
#   'name': 'tyrion lannister',
#   'sentence': 'You will. On horseback you will be as tall as any of them.',
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['You',
#    'will',
#    '.',
#    'On',
#    'horseback',
#    'you',
#    'will',
#    'be',
#    'as',
#    'tall',
#    'as',
#    'any',
#    'of',
#    'them',
#    '.'],
#   'alphanumeric_words': ['You',
#    'will',
#    'On',
#    'horseback',
#    'you',
#    'will',
#    'be',
#    'as',
#    'tall',
#    'as',
#    'any',
#    'of',
#    'them'],
#   'word_count': 13},
#  {'release_date': '2011-05-08',
#   'season': 'Season 1',
#   'episode': 'Episode 4',
#   'episode_title': 'Cripples, Bastards and Broken Things',
#   'name': 'robb stark',
#   'sentence': 'Is this some kind of trick? Why do you want to help him?',
#   'positive_score': 0.275,
#   'compound_score': 0.4342,
#   'neutral_score': 0.631,
#   'negative_score': 0.094,
#   'tokenized_words': ['Is',
#    'this',
#    'some',
#    'kind',
#    'of',
#    'trick',
#    '?',
#    'Why',
#    'do',
#    'you',
#    'want',
#    'to',
#    'help',
#    'him',
#    '?'],
#   'alphanumeric_words': ['Is',
#    'this',
#    'some',
#    'kind',
#    'of',
#    'trick',
#    'Why',
#    'do',
#    'you',
#    'want',
#    'to',
#    'help',
#    'him'],
#   'word_count': 13},
#  {'release_date': '2011-05-08',
#   'season': 'Season 1',
#   'episode': 'Episode 4',
#   'episode_title': 'Cripples, Bastards and Broken Things',
#   'name': 'tyrion lannister',
#   'sentence': 'I have a tender spot in my heart for cripples, bastards and broken things.',
#   'positive_score': 0.188,
#   'compound_score': -0.4404,
#   'neutral_score': 0.493,
#   'negative_score': 0.318,
#   'tokenized_words': ['I',
#    'have',
#    'a',
#    'tender',
#    'spot',
#    'in',
#    'my',
#    'heart',
#    'for',
#    'cripples',
#    ',',
#    'bastards',
#    'and',
#    'broken',
#    'things',
#    '.'],
#   'alphanumeric_words': ['I',
#    'have',
#    'a',
#    'tender',
#    'spot',
#    'in',
#    'my',
#    'heart',
#    'for',
#    'cripples',
#    'bastards',
#    'and',
#    'broken',
#    'things'],
#   'word_count': 14},
#  {'release_date': '2011-05-08',
#   'season': 'Season 1',
#   'episode': 'Episode 4',
#   'episode_title': 'Cripples, Bastards and Broken Things',
#   'name': 'robb stark',
#   'sentence': "You've done my brother a kindness. The hospitality of Winterfell is yours.",
#   'positive_score': 0.214,
#   'compound_score': 0.4588,
#   'neutral_score': 0.786,
#   'negative_score': 0.0,
#   'tokenized_words': ['You',
#    "'ve",
#    'done',
#    'my',
#    'brother',
#    'a',
#    'kindness',
#    '.',
#    'The',
#    'hospitality',
#    'of',
#    'Winterfell',
#    'is',
#    'yours',
#    '.'],
#   'alphanumeric_words': ['You',
#    'done',
#    'my',
#    'brother',
#    'a',
#    'kindness',
#    'The',
#    'hospitality',
#    'of',
#    'Winterfell',
#    'is',
#    'yours'],
#   'word_count': 12},
#  {'release_date': '2011-05-08',
#   'season': 'Season 1',
#   'episode': 'Episode 4',
#   'episode_title': 'Cripples, Bastards and Broken Things',
#   'name': 'tyrion lannister',
#   'sentence': "Spare me your false courtesies, Lord Stark. There's a brothel outside your walls. There I'll find a bed and both of us can sleep easier.",
#   'positive_score': 0.104,
#   'compound_score': 0.4215,
#   'neutral_score': 0.896,
#   'negative_score': 0.0,
#   'tokenized_words': ['Spare',
#    'me',
#    'your',
#    'false',
#    'courtesies',
#    ',',
#    'Lord',
#    'Stark',
#    '.',
#    'There',
#    "'s",
#    'a',
#    'brothel',
#    'outside',
#    'your',
#    'walls',
#    '.',
#    'There',
#    'I',
#    "'ll",
#    'find',
#    'a',
#    'bed',
#    'and',
#    'both',
#    'of',
#    'us',
#    'can',
#    'sleep',
#    'easier',
#    '.'],
#   'alphanumeric_words': ['Spare',
#    'me',
#    'your',
#    'false',
#    'courtesies',
#    'Lord',
#    'Stark',
#    'There',
#    'a',
#    'brothel',
#    'outside',
#    'your',
#    'walls',
#    'There',
#    'I',
#    'find',
#    'a',
#    'bed',
#    'and',
#    'both',
#    'of',
#    'us',
#    'can',
#    'sleep',
#    'easier'],
#   'word_count': 25},
#  {'release_date': '2011-05-08',
#   'season': 'Season 1',
#   'episode': 'Episode 4',
#   'episode_title': 'Cripples, Bastards and Broken Things',
#   'name': 'theon greyjoy',
#   'sentence': "Couldn't resist some northern ass? If you like redheads, ask for Ros.",
#   'positive_score': 0.156,
#   'compound_score': -0.25,
#   'neutral_score': 0.625,
#   'negative_score': 0.219,
#   'tokenized_words': ['Could',
#    "n't",
#    'resist',
#    'some',
#    'northern',
#    'ass',
#    '?',
#    'If',
#    'you',
#    'like',
#    'redheads',
#    ',',
#    'ask',
#    'for',
#    'Ros',
#    '.'],
#   'alphanumeric_words': ['Could',
#    'resist',
#    'some',
#    'northern',
#    'ass',
#    'If',
#    'you',
#    'like',
#    'redheads',
#    'ask',
#    'for',
#    'Ros'],
#   'word_count': 12},
#  {'release_date': '2011-05-08',
#   'season': 'Season 1',
#   'episode': 'Episode 4',
#   'episode_title': 'Cripples, Bastards and Broken Things',
#   'name': 'tyrion lannister',
#   'sentence': "Come to see me off, Greyjoy? Kind of you. Your master doesn't seem to like Lannisters.",
#   'positive_score': 0.0,
#   'compound_score': -0.2755,
#   'neutral_score': 0.877,
#   'negative_score': 0.123,
#   'tokenized_words': ['Come',
#    'to',
#    'see',
#    'me',
#    'off',
#    ',',
#    'Greyjoy',
#    '?',
#    'Kind',
#    'of',
#    'you',
#    '.',
#    'Your',
#    'master',
#    'does',
#    "n't",
#    'seem',
#    'to',
#    'like',
#    'Lannisters',
#    '.'],
#   'alphanumeric_words': ['Come',
#    'to',
#    'see',
#    'me',
#    'off',
#    'Greyjoy',
#    'Kind',
#    'of',
#    'you',
#    'Your',
#    'master',
#    'does',
#    'seem',
#    'to',
#    'like',
#    'Lannisters'],
#   'word_count': 16},
#  {'release_date': '2011-05-08',
#   'season': 'Season 1',
#   'episode': 'Episode 4',
#   'episode_title': 'Cripples, Bastards and Broken Things',
#   'name': 'theon greyjoy',
#   'sentence': "He's not my master.",
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['He', "'s", 'not', 'my', 'master', '.'],
#   'alphanumeric_words': ['He', 'not', 'my', 'master'],
#   'word_count': 4},
#  {'release_date': '2011-05-08',
#   'season': 'Season 1',
#   'episode': 'Episode 4',
#   'episode_title': 'Cripples, Bastards and Broken Things',
#   'name': 'tyrion lannister',
#   'sentence': "No, of course not. What happened here? Where is lady Stark? Why didn't she receive me?",
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['No',
#    ',',
#    'of',
#    'course',
#    'not',
#    '.',
#    'What',
#    'happened',
#    'here',
#    '?',
#    'Where',
#    'is',
#    'lady',
#    'Stark',
#    '?',
#    'Why',
#    'did',
#    "n't",
#    'she',
#    'receive',
#    'me',
#    '?'],
#   'alphanumeric_words': ['No',
#    'of',
#    'course',
#    'not',
#    'What',
#    'happened',
#    'here',
#    'Where',
#    'is',
#    'lady',
#    'Stark',
#    'Why',
#    'did',
#    'she',
#    'receive',
#    'me'],
#   'word_count': 16},
#  {'release_date': '2011-05-08',
#   'season': 'Season 1',
#   'episode': 'Episode 4',
#   'episode_title': 'Cripples, Bastards and Broken Things',
#   'name': 'theon greyjoy',
#   'sentence': "She wasn't feeling well.",
#   'positive_score': 0.0,
#   'compound_score': -0.2924,
#   'neutral_score': 0.386,
#   'negative_score': 0.614,
#   'tokenized_words': ['She', 'was', "n't", 'feeling', 'well', '.'],
#   'alphanumeric_words': ['She', 'was', 'feeling', 'well'],
#   'word_count': 4},
#  {'release_date': '2011-05-08',
#   'season': 'Season 1',
#   'episode': 'Episode 4',
#   'episode_title': 'Cripples, Bastards and Broken Things',
#   'name': 'tyrion lannister',
#   'sentence': "She's not in Winterfell, is she? Where did she go?",
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['She',
#    "'s",
#    'not',
#    'in',
#    'Winterfell',
#    ',',
#    'is',
#    'she',
#    '?',
#    'Where',
#    'did',
#    'she',
#    'go',
#    '?'],
#   'alphanumeric_words': ['She',
#    'not',
#    'in',
#    'Winterfell',
#    'is',
#    'she',
#    'Where',
#    'did',
#    'she',
#    'go'],
#   'word_count': 10},
#  {'release_date': '2011-05-08',
#   'season': 'Season 1',
#   'episode': 'Episode 4',
#   'episode_title': 'Cripples, Bastards and Broken Things',
#   'name': 'theon greyjoy',
#   'sentence': "My lady's whereabouts...",
#   'positive_score': 0.0,
#   'compound_score': 0.0,
#   'neutral_score': 1.0,
#   'negative_score': 0.0,
#   'tokenized_words': ['My', 'lady', "'s", 'whereabouts', '...'],
#   'alphanumeric_words': ['My', 'lady', 'whereabouts'],
#   'word_count': 3},
#  {'release_date': '2011-05-08',
#   'season': 'Season 1',
#   'episode': 'Episode 4',
#   'episode_title': 'Cripples, Bastards and Broken Things',
#   'name': 'tyrion lannister',
#   'sentence': "My lady? Your loyalty to your captors is touching. Tell me, how do you think Balon Greyjoy would feel if he could see his only surviving son has turned lackey? I still remember seeing my father's fleet burn in Lannisport. I believe your uncles were responsible?",
#   'positive_score': 0.166,
#   'compound_score': 0.8196,
#   'neutral_score': 0.834,
#   'negative_score': 0.0,
#   'tokenized_words': ['My',
#    'lady',
#    '?',
#    'Your',
#    'loyalty',
#    'to',
#    'your',
#    'captors',
#    'is',
#    'touching',
#    '.',
#    'Tell',
#    'me',
#    ',',
#    'how',
#    'do',
#    'you',
#    'think',
#    'Balon',
#    'Greyjoy',
#    'would',
#    'feel',
#    'if',
#    'he',
#    'could',
#    'see',
#    'his',
#    'only',
#    'surviving',
#    'son',
#    'has',
#    'turned',
#    'lackey',
#    '?',
#    'I',
#    'still',
#    'remember',
#    'seeing',
#    'my',
#    'father',
#    "'s",
#    'fleet',
#    'burn',
#    'in',
#    'Lannisport',
#    '.',
#    'I',
#    'believe',
#    'your',
#    'uncles',
#    'were',
#    'responsible',
#    '?'],
#   'alphanumeric_words': ['My',
#    'lady',
#    'Your',
#    'loyalty',
#    'to',
#    'your',
#    'captors',
#    'is',
#    'touching',
#    'Tell',
#    'me',
#    'how',
#    'do',
#    'you',
#    'think',
#    'Balon',
#    'Greyjoy',
#    'would',
#    'feel',
#    'if',
#    'he',
#    'could',
#    'see',
#    'his',
#    'only',
#    'surviving',
#    'son',
#    'has',
#    'turned',
#    'lackey',
#    'I',
#    'still',
#    'remember',
#    'seeing',
#    'my',
#    'father',
#    'fleet',
#    'burn',
#    'in',
#    'Lannisport',
#    'I',
#    'believe',
#    'your',
#    'uncles',
#    'were',
#    'responsible'],
#   'word_count': 46},
#  ...]

# %%
# connections to mongo db
client = MongoClient('mongodb://localhost:27017/')

# setting variable for db
db = client.sent_analysisdb

# setting variable for collection in db
col = db.got_scripts

# %%
# inserts dictionary into db
col.insert_many(script_dict)


# verifys succesful import
col.find_one()
